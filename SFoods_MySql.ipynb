# %% [markdown]
# #### Writing products in MySQL-Azure

# %%
#import pymysql
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from random import randint
# %matplotlib inline

# %%
#from mysql.connector import (connection)
import mysql.connector
from mysql.connector import errorcode

# %%
config = {
  'host':'xxx.mysql.database.azure.com',
  'user':'lmoliveira@xxx',
  'password':'xxx!',
  'database':'xxxb'
}

# %%
try:
   conn = mysql.connector.connect(**config)
   print("Connection established")
except mysql.connector.Error as err:
  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with the user name or password")
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  else:
    print(err)
else:
  cursor = conn.cursor()

  # Update a data row in the table
  # cursor.execute("UPDATE inventory SET quantity = %s WHERE name = %s;", (200, "banana"))
  # print("Updated",cursor.rowcount,"row(s) of data.")

  # Cleanup
  #conn.commit()
  #cursor.close()
  #conn.close()
  #print("Done.")
# Out:
# 9000 (HY000): Client with IP address '179.210.57.53' is not allowed to connect to this MySQL server.

# %%
df = pd.read_csv('C:\Mettricx\Projetos\SupraAlimentos\DataSet\supraProdutos.csv', dtype={'cod': object, 'NF': object, 'CNPJ': object})

# %%
import sys  
import os

filepath = 'C:\Mettricx\Projetos\SupraAlimentos\DataSet\supraProdutos.csv' 
palavras = []
with open(filepath, 'r', encoding='utf-8') as fp:
  
   #line = fp.readline() 
   cnt = 0
   for line in fp:
       #palavras = (line.strip().split(','))
       #print(palavras[0])
       #print(palavras[1])
       #print(palavras[2])
       #cursor.execute("INSERT INTO `marketdb`.`produtos` (`Empresa_idEmpresa`, `codProduto`,`NomeProduto`,`Unidade`) "+
                     " VALUES " + "("+"2000"+","+"'"+palavras[0]+"'"+","+"'"+palavras[2]+"'"+","+"'"+palavras[1]+"'"+")")




    
   #campos = line.strip().split(' ')
   #cnt = 1
   #while line:
   #    print("Line {}: {}".format(cnt, line.strip()))
   #    line = fp.readline()
   #    cnt += 1
# Out:
# 020002
# UN
# ALHO E CEBOLA  PICADINHO S/SAL  180GR
# 010002
# UN
# ALECRIM 15GR
# 010001
# UN
# ACAFRAO 15GR
# 010009
# UN
# CALDO DE CARNE  COM ERVAS FINAS  60GR
# 010010
# UN
# CALDO DE  GALINHA COM  ERVAS FINAS 60GR
# 010007
# UN
# CALDO DE BACON  COM ERVAS FINAS  60GR
# 030003
# UN
# MOLHO ARABE  150ML.
# 010006
# UN
# BICARBONATO DE  SODIO 100GR
# 010008
# UN
# CALDO DE  CAMARAO COM  ERVAS FINAS 60GR
# 010011
# UN
# CALDO DE PEIXE  COM ERVAS FINAS  60GR
# 010038
# UN
# TEMPERO  COMPLETO COM  ERVAS FINAS 60GR
# 010041
# UN
# COLORIFICO  EXTRA 60GR
# 010042
# UN
# COLORIFICO  EXTRA 100GR
# 010043
# UN
# COLORIFICO  EXTRA 200GR
# 020006
# UN
# COLORIFICO DA  ROCA 150GR
# 020007
# UN
# COLORIFICO  NORDESTINO  200GR
# 010044
# UN
# CONFEITO  CHOCOLATE  GRANULADO 100GR
# 010045
# UN
# CONFEITO  CHOCOLATE  REDONDO 100GR
# 010046
# UN
# CONFEITO  COLORIDO  GRANULADO 100GR
# 020020
# UN
# ALHO E SAL 300GR
# 030014
# UN
# MOLHO SHOYU  150ML
# 010047
# UN
# ...

# %%
conn.commit()
cursor.close()
conn.close()
print("Done.")
# Out:
# Done.

# %%
row = cursor.fetchone()
cursor.execute("SELECT * FROM books")
